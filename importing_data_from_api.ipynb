# %%
import pandas as pd

# %%
pd.read_json("train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
##from url
##api data

import pandas as pd
import requests

# %%
response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=2090d94c4d1e786683c17d059ed3d9c8")

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/caBIySpwuFi2i7ynvHIlnxJLOdN.jpg',
#   'genre_ids': [16, 28, 12, 878],
#   'id': 1560520,
#   'title': 'Batman: Knightfall Part 1: Knightfall',
#   'original_language': 'en',
#   'original_title': 'Batman: Knightfall Part 1: Knightfall',
#   'overview': 'Arkham Asylum has been destroyed, and all its inmates have been unleashed upon Gotham City. As Batman races to round up some of his greatest enemies, he is pushed to his physical and mental limits and into a final confrontation with a new threat: the man called Bane!',
#   'popularity': 82.3541,
#   'poster_path': '/360qdtu2hLnqMu8SVHMywn420w1.jpg',
#   'release_date': '2026-06-23',
#   'softcore': False,
#   'video': False,
#   'vote_average': 9.174,
#   'vote_count': 321},
#  {'adult': False,
#   'backdrop_path': '/ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg',
#   'genre_ids': [16, 12, 14, 28],
#   'id': 980431,
#   'title': 'Avatar Aang: The Last Airbender',
#   'original_language': 'en',
# ...

# %%
temp_df=pd.DataFrame(response.json()["results"]).head(2)[["id","title","overview","popularity","vote_average","vote_count"]]

# %%
temp_df.head(4)
# Out:
#         id                                  title  \
# 0  1560520  Batman: Knightfall Part 1: Knightfall
# 1   980431        Avatar Aang: The Last Airbender
#
#                                             overview  popularity  \
# 0  Arkham Asylum has been destroyed, and all its ...     82.3541
# 1  Avatar Aang, the world's last Airbender, learn...     87.8050
#
#    vote_average  vote_count
# 0         9.174         321
# 1         9.139        1138

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=2090d94c4d1e786683c17d059ed3d9c8&page={}".format(i))
    temp_df=pd.DataFrame(response.json()["results"]).head(2)[["id","title","overview","popularity","vote_average","vote_count"]]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#           id                                  title  \
# 0    1560520  Batman: Knightfall Part 1: Knightfall
# 1     980431        Avatar Aang: The Last Airbender
# 2    1560520  Batman: Knightfall Part 1: Knightfall
# 3     980431        Avatar Aang: The Last Airbender
# 4    1560520  Batman: Knightfall Part 1: Knightfall
# ..       ...                                    ...
# 851   980431        Avatar Aang: The Last Airbender
# 852  1560520  Batman: Knightfall Part 1: Knightfall
# 853   980431        Avatar Aang: The Last Airbender
# 854  1560520  Batman: Knightfall Part 1: Knightfall
# 855   980431        Avatar Aang: The Last Airbender
#
#                                               overview  popularity  \
# 0    Arkham Asylum has been destroyed, and all its ...     82.3541
# 1    Avatar Aang, the world's last Airbender, learn...     87.8050
# 2    Arkham Asylum has been destroyed, and all its ...     82.3541
# ...

# %%
df.shape
# Out:
# (856, 6)

# %%
df.to_csv("movies.csv")
